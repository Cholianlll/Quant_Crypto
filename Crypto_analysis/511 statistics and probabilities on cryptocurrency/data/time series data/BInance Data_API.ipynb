# %% [markdown]
# # Introduction

# %% [markdown]
# API doc:https://binance-docs.github.io/apidocs/spot/en/

# %% [markdown]
# The Following API can return all historical trading related data of tokens activated in Binance enchanges.

# %%
# Packages
import time
import json

import requests
import pandas as pd
import numpy as np
import datetime
from urllib.parse import urljoin, urlencode
from dateutil import parser

# %% [markdown]
# # Obtian the exchange info

# %%
# Obtain the exchange information firstly
def exchangeInfo():
    BASE_URL = 'https://api.binance.com'
    PATH = '/api/v3/exchangeInfo'
    
    url = urljoin(BASE_URL, PATH)
    
    response = requests.get(url)

    data = response.json()
    data = pd.DataFrame(data['symbols'])
    return data

# %%
tokenInfo = exchangeInfo()

tokenInfo.head()
# Out:
#     symbol   status baseAsset  baseAssetPrecision quoteAsset  quotePrecision  \
# 0   ETHBTC  TRADING       ETH                   8        BTC               8
# 1   LTCBTC  TRADING       LTC                   8        BTC               8
# 2   BNBBTC  TRADING       BNB                   8        BTC               8
# 3   NEOBTC  TRADING       NEO                   8        BTC               8
# 4  QTUMETH  TRADING      QTUM                   8        ETH               8
#
#    quoteAssetPrecision  baseCommissionPrecision  quoteCommissionPrecision  \
# 0                    8                        8                         8
# 1                    8                        8                         8
# 2                    8                        8                         8
# 3                    8                        8                         8
# 4                    8                        8                         8
#
#                                           orderTypes  icebergAllowed  \
# 0  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True
# 1  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True
# 2  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True
# 3  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True
# 4  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True
#
#    ocoAllowed  quoteOrderQtyMarketAllowed  isSpotTradingAllowed  \
# 0        True                        True                  True
# 1        True                        True                  True
# 2        True                        True                  True
# 3        True                        True                  True
# 4        True                        True                  True
#
#    isMarginTradingAllowed                                            filters  \
# 0                    True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...
# 1                    True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...
# 2                    True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...
# 3                    True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...
# 4                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...
#
#       permissions
# 0  [SPOT, MARGIN]
# 1  [SPOT, MARGIN]
# 2  [SPOT, MARGIN]
# 3  [SPOT, MARGIN]
# 4          [SPOT]

# %%
tokenInfo.to_csv("Exchange_info.csv")

# example
tokenInfo['symbol'][0]
# Out:
# 'ETHBTC'

# %% [markdown]
# # obtain the historicl data of tokens

# %% [markdown]
# Binance exchange provides from monthly frequency data to minute frequency data.

# %%
# timedelta_fre = ['W','D','hours','m','s','ms']
itv = ["1m","3m","5m","15m","30m","1h","2h","4h","6h","8h","12h","1d","3d","1w","1M"]

# historical of token price should be indexed by its symbol.
smb = tokenInfo['symbol']

# %%
def start_end_time(startTime,interval,length = 1000):
#     Due to the limit of the api, we need a function to help cut a long time into small period.
#     The function input the start time and interval and return the start time and endtime. 
#     
#     read the time
    startTime = datetime.datetime.strptime(startTime, "%Y-%m-%d %H:%M:%S")
    
#     unit 
    unit = interval
#     transfer the interval frequence
    if unit in ["1m","3m","5m","15m","30m"]:
        unit = 'm'
    elif unit in ["1h","2h","4h","6h","8h","12h"]:
        unit = 'hours'
    elif unit in ["1d","3d"]:
        unit = 'D'
    else:
        unit = 'W'
        
    endTime = pd.to_datetime(startTime)+pd.to_timedelta(length, unit = unit)

    startTime = datetime.datetime.timestamp(startTime)*1000
    endTime = datetime.datetime.timestamp(endTime)*1000
    
    return str(int(startTime)),str(int(endTime))

# %%
def klines(symbol,startTime,endTime,interval):
#    This function is aimed to gather the historical price data.    
    BASE_URL = 'https://api.binance.com'
    PATH = '/api/v3/klines'
    
    params = {
        'symbol': symbol,
        'interval': interval,
        'startTime':startTime,
        'endTime':endTime,
        'limit':1000 # 500/1000 is the limit for each request
    }

    url = urljoin(BASE_URL, PATH)

    response = requests.get(url,params=params)

    data = response.json()
    data = pd.DataFrame(data)
#     change the cols
    col = ['Open time','Open','High','Low','Close','Volume','Close time','Quote asset volume','Number of trades',
       'Taker buy base asset volume','Taker buy quote asset volume','Ignore']
    
    if not data.empty:
        data.columns = col
#       transfer the timestamp into time
        data['Open time'] = pd.to_datetime(data['Open time'],unit='ms',utc=True)
        data['Close time'] = pd.to_datetime(data['Close time'],unit='ms',utc=True)
        return data
    else:
        print('No data')

# %% [markdown]
# # Sample of data

# %% [markdown]
# After build the function of API and exchange information, we can now obtain every token with every period data.

# %% [markdown]
# For example, we here use famous 1m BTC as our data sample.

# %%
smb[12]
# Out:
# 'ETHUSDT'

# %%
itv[0]
# Out:
# '1m'

# %%
symbol = smb[11]
interval = itv[0]

startTime = '2021-09-01 00:00:00'
[startTime,endTime] = start_end_time(startTime=startTime,interval=interval)

data = klines(symbol=symbol,startTime=startTime,endTime=endTime,interval=interval)

# %%
data.head()
# Out:
#                   Open time            Open            High             Low  \
# 0 2021-09-01 04:00:00+00:00  47043.65000000  47054.78000000  46991.96000000
# 1 2021-09-01 04:01:00+00:00  47009.38000000  47025.24000000  46980.02000000
# 2 2021-09-01 04:02:00+00:00  46995.37000000  47020.26000000  46969.56000000
# 3 2021-09-01 04:03:00+00:00  46995.11000000  47020.00000000  46984.68000000
# 4 2021-09-01 04:04:00+00:00  47010.02000000  47017.25000000  46985.33000000
#
#             Close       Volume                       Close time  \
# 0  47009.38000000  16.04384000 2021-09-01 04:00:59.999000+00:00
# 1  46995.37000000  22.86129000 2021-09-01 04:01:59.999000+00:00
# 2  46995.11000000  19.67009000 2021-09-01 04:02:59.999000+00:00
# 3  47010.03000000  12.12577000 2021-09-01 04:03:59.999000+00:00
# 4  46985.35000000  10.84569000 2021-09-01 04:04:59.999000+00:00
#
#   Quote asset volume  Number of trades Taker buy base asset volume  \
# 0    754341.09833020               667                  8.45966000
# 1   1074492.76913610               533                 12.05659000
# 2    924338.18065390               456                  9.16799000
# 3    569978.26374720               371                  6.85744000
# 4    509797.02832680               426                  6.61054000
#
#   Taker buy quote asset volume Ignore
# 0              397743.66640310      0
# 1              566711.30732960      0
# 2              430803.69030850      0
# 3              322347.16252190      0
# 4              310725.14683290      0

# %%
data.to_csv('BTC_1min.csv')

# %%
import time

# %%
alldata = pd.DataFrame()

interval = itv[11]
for i in range(len(smb)):
    symbol = smb[i]
    
    time.sleep(0.01)
    
    startTime = '2021-08-31 00:00:00'
    [startTime,endTime] = start_end_time(startTime=startTime,interval=interval)

    data = klines(symbol=symbol,startTime=startTime,endTime=endTime,interval=interval)
    try:
        data['token'] = symbol
        alldata = pd.concat([alldata,data],axis = 0)
    except:
        continue
# Out:
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# No data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/4g/jz_j1_cd25v2bv9plmhlqqw80000gn/T/ipykernel_18336/3379404804.py in <module>
#      10     [startTime,endTime] = start_end_time(startTime=startTime,interval=interval)
#      11
# ---> 12     data = klines(symbol=symbol,startTime=startTime,endTime=endTime,interval=interval)
#      13     try:
#      14         data['token'] = symbol
#
# /var/folders/4g/jz_j1_cd25v2bv9plmhlqqw80000gn/T/ipykernel_18336/1834641510.py in klines(symbol, startTime, endTime, interval)
#      14     url = urljoin(BASE_URL, PATH)
#      15
# ---> 16     response = requests.get(url,params=params)
#      17
#      18     data = response.json()
#
# ~/opt/anaconda3/envs/myenv/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/envs/myenv/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/envs/myenv/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/envs/myenv/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/myenv/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/envs/myenv/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/opt/anaconda3/envs/myenv/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/envs/myenv/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/myenv/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/envs/myenv/lib/python3.9/http/client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# ~/opt/anaconda3/envs/myenv/lib/python3.9/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~/opt/anaconda3/envs/myenv/lib/python3.9/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~/opt/anaconda3/envs/myenv/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/myenv/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/myenv/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
alldata.to_csv('tokens_ts_from20210901.csv',encoding='utf8')
